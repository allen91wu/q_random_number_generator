# %%
# !pip install qiskit

# !pip install q_random_number_generator

# %%
import q_random_number_generator as qrand

# %%
quantum = qrand.generate(-10,10,100)
print(quantum)
# Out:
# [-10, 6, 9, 7, -5, -1, -1, -9, 9, -8, 6, 7, 8, -5, -8, -9, -7, -10, -4, -1, -5, 6, -2, 1, 2, 3, -4, 2, 3, 8, -6, -10, -2, -8, 0, -7, -4, 0, -6, -3, -8, 3, -8, 7, -7, -9, 1, 3, 1, 6, -1, 1, 5, 2, -2, 7, -9, -4, -3, -6, 2, 1, -7, 2, 3, 2, -6, 7, -5, 4, 6, 2, 6, -1, 3, 10, -2, -7, -7, -8, -7, -2, 10, 6, 0, 1, 8, 9, 8, -2, 5, 10, 7, 1, 4, -7, 10, 2, 0, 0]

# %%
import matplotlib.pyplot as plt

plt.hist(quantum, bins=20)
plt.show()
